# %%
import numpy as np
import pandas as pd
import geopandas as gp
#import pylab as pl 
#import json
#import fiona
import statsmodels.formula.api as smf
import scipy.stats
#from math import log1p
#from sklearn.decomposition import PCA
#from matplotlib.mlab import PCA as mlabPCA
import matplotlib  
import matplotlib.pyplot as plt  
#Inline Plotting for Ipython Notebook 
# %matplotlib inline

#%pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('http://localhost:8888/files/Google%20Drive/Internship_TLC%20Enforcement/2016_Green_Taxi_Trip_Data.csv')

# %%
pd.options.display.mpl_style = 'default' #Better Styling  
new_style = {'grid': False} #Remove grid  
matplotlib.rc('axes', **new_style)  
from matplotlib import rcParams  
rcParams['figure.figsize'] = (17.5, 17) #Size of figure  
rcParams['figure.dpi'] = 250

P=df.plot(kind='scatter', x='Pickup_longitude', y='Pickup_latitude',color='green',xlim=(-74.06,-73.77),ylim=(40.43, 40.91),s=.02,alpha=.6)
P.set_axis_bgcolor('black') #Background Color

# %%
pd.options.display.mpl_style = 'default' #Better Styling  
new_style = {'grid': False} #Remove grid  
matplotlib.rc('axes', **new_style)  
#from matplotlib import rcParams  
rcParams['figure.figsize'] = (17.5, 17) #Size of figure  
rcParams['figure.dpi'] = 250

P=df.plot(kind='scatter', x='Dropoff_longitude', y='Dropoff_latitude',color='red',xlim=(-74.06,-73.77),ylim=(40.61, 40.91),s=.02,alpha=.6)
P.set_axis_bgcolor('black') #Background Color
